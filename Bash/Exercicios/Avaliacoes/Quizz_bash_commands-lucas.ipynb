# %%
import sh

# %% [markdown]
# No Jupyter notebook, existem duas maneiras de interagir com o shell.
#
# + Usando o múdulo sh
# + Colocando uma exclamação antes da linha na célula
#
# Veja os exemplos:

# %%
sh.touch('teste.txt')

# %%
# !echo 'um texto interessante' > teste2.txt

# %% [markdown]
# Resolva as seguintes tarefas:

# %% [markdown]
# 1 - Acesse o arquivo "Genesis.txt" na pasta correta e conte o número de ocorrências da palavra "God" (desconderar as vezes em que as letras fazem parte de outra palavra)

# %%
#sh.cat('../../Dados/genesis.txt')
# !cat '../../Dados/genesis.txt' | tr -sc 'God' '[\012*]' | sort | uniq -c | grep 'God'
# Out:
#     233 God

# %% [markdown]
# 2 - Descubra os nomes próprios do arquivo acima

# %%
# !cat ../../Dados/genesis.txt | tr -sc '[a-z][A-Z]' '[\012*]'| grep -e '[A-Z][a-z]*' | sort | uniq

# %% [markdown]
# 3 - Descubra a palavra que mais ocorre em uma única linha

# %%
# !cat

# %% [markdown]
# 4 - Crie um novo texto (genesis2.txt) em que os números no início da linha são retirados

# %%
# !cat ../../Dados/genesis.txt /
# Out:
# GREP(1)                     General Commands Manual                    GREP(1)
#
# E
#        grep, egrep, fgrep, rgrep - print lines matching a pattern
#
# S
# E...]
# E...]
#
# N
# Es for lines containing a match to the
# -” is given,
# p prints the matching
#        lines.
#
# p are  the  same
# r, respectively.  These variants are
#        deprecated, but are provided for backward compatibility.
#
# S
# n
# p Output a usage message and exit.
#
# n
# p and exit.
#
# n
# p
# N as an extended regular  expression  (ERE,  see
#               below).
#
# s
# N as a list of fixed strings (instead of regular
#               expressions), separated by newlines,  any  of  which  is  to  be
#               matched.
#
# p
# N  as  a  basic  regular  expression  (BRE, see
#               below).  This is the default.
#
# p
#               Interpret the pattern as a  Perl-compatible  regular  expression
# P may warn of
#               unimplemented features.
#
# l
# N
# ...
