# %% [markdown]
# ## Exercícios - ["Unix for Poets"](https://www.cs.upc.edu/~padro/Unixforpoets.pdf)

# %% [markdown]
# Vamos demonstrar o uso dos seguintes programas do Unix / Linux:
# + cat
# + tr
# + wc
# + sort
# + uniq
# + head
# + tail
# + sed
# + rev
# + paste
# + grep / egrep

# %%
# !pwd

# %% [markdown]
# #### 1) Contando palavras em um texto

# %% [markdown]
# #### 2) Ordenando uma lista de palavras de várias maneiras
# + ordem ascii
# + ordem alfabética
# + ordem de "rima"

# %%
! tr -sc '[A-Z][a-z]' '[\012*]' < ./Dados/genesis.txt | sort | uniq | head

# %%
! tr -sc '[A-Z][a-z]' '[\012*]' < ./Dados/genesis.txt | sort | uniq -c | head

# %%
! cat ./Dados/genesis.txt | tr -sc '[A-Z][a-z]' '[\012*]' | sort | uniq -c | sort -nr | sed 10q

# %%
! cat ./Dados/genesis.txt | tr '[a-z]' '[A-Z]' | tr -sc '[A-Z]' '[\012*]' | sort | uniq | sed 10q

# %%
! cat ./Dados/genesis.txt | tr '[a-z]' '[A-Z]' | tr -sc 'A-Z' '\n' | sort | uniq -c | sort -gr | sed 10q

# %%
# !cat ./Dados/genesis.txt | tr -sc '[A-Z][a-z]' '[\012*]' | rev | sort | rev | uniq -c | sed -n '100,120p'

# %% [markdown]
# #### 3) Encontrando n-gramas

# %%
! cat ./Dados/genesis.txt | tr -sc '[A-Z][a-z]' '[\012*]' > ./Dados/genesis.words
! tail -n +2 ./Dados/genesis.words > ./Dados/genesis.nextwords
! paste ./Dados/genesis.words ./Dados/genesis.nextwords | sort | uniq -c | sort -nr > ./Dados/genesis.bigrams

# %%
! cat ./Dados/genesis.bigrams | head

# %%
! paste ./Dados/genesis.words ./Dados/genesis.nextwords | sort | uniq -c | sort -gr > ./Dados/genesis.bigrams.freq

# %%
! cat ./Dados/genesis.bigrams.freq | head

# %%
! cat ./Dados/genesis.txt | tr -sc '[A-Z][a-z]' '[\012*]' > genesis.words
! tail -n +2 ./Dados/genesis.words > ./Dados/genesis.nextwords
! tail -n +3 ./Dados/genesis.words > ./Dados/genesis.nextwords2
! paste ./Dados/genesis.words ./Dados/genesis.nextwords ./Dados/genesis.nextwords2 | sort | uniq -c > ./Dados/genesis.trigrams

# %%
! cat ./Dados/genesis.trigrams | head

# %%
# !paste ./Dados/genesis.words ./Dados/genesis.nextwords ./Dados/genesis.nextwords2 | sort | uniq -c | sort -gr > ./Dados/genesis.trigrams.freq

# %%
! cat ./Dados/genesis.trigrams.freq | head

# %% [markdown]
# #### 4) Buscando por padrões com [grep and egrep](https://www.digitalocean.com/community/tutorials/using-grep-regular-expressions-to-search-for-text-patterns-in-linux)

# %% [raw]
# Example               Explanation
# ___________________________________________
# grep gh          find lines containing ‘‘gh’’
# grep ’ˆcon’      find lines beginning with ‘‘con’’
# grep ’ing$’      find lines ending with ‘‘ing’
# grep –v gh       delete lines containing ‘‘gh’’
# grep –v ’ˆcon’   delete lines beginning with ‘‘con’’
# grep –v ’ing$’   delete lines ending with ‘‘ing’’

# %% [raw]
# Grep allows ranges of characters (somewhat) like tr.
# Example              Explanation
# ___________________________________________________
# grep ’[A–Z]’         lines with an uppercase char
# grep ’ˆ[A–Z]’        lines starting with an uppercase char
# grep ’[A–Z]$’        lines ending with an uppercase char
# grep ’ˆ[A–Z]*$’      lines with all uppercase chars
# grep ’[aeiouAEIOU]’  lines with a vowel
# grep ’^[aeiouAEIOU]’ lines starting with a vowel
# grep ’[aeiouAEIOU]$’ lines ending with a vowel

# %%
cat ./Dados/genesis.txt | grep 'the land of' | sed 10q

# %%
! cat ./Dados/genesis.txt | grep 'God' | wc -l

# %%
! cat ./Dados/genesis.txt | grep -o 'God' | wc -w

# %%
! cat ./Dados/genesis.txt | grep -io 'God' | wc -w

# %%
! cat ./Dados/genesis.txt | tr '[A-Z]' '[a-z]' | tr -sc '[a-z]' '[\012*]' | grep 'god' | wc -l

# %% [markdown]
# #### Retirando os números e encontrando a palavra God

# %%
! cat ./Dados/genesis.txt | tr -d '[0-9:]' | grep 'God' | sed 10q

# %% [markdown]
# #### Linhas que não começam por "And"

# %%
! cat ./Dados/genesis.txt | sed 's/[0-9]*:[0-9]* //g' | grep '^God'

# %%
! cat ./Dados/genesis.txt | sed 's/[0-9]*:[0-9]* //g' | grep -v '^And' | sed 10q

# %% [markdown]
# #### Exercícios com grep / egrep
#
# 1) Quantas palavras maiúsculas há no Genesis?
# 2) Quantas palavras de 4 letras?
# 3) Há palavras sem vogais?
# 4) Há palavras com apenas uma sílaba (somente uma vogal)?
# 5) Encontre as palavras com exatemente duas sílabas (duas vogais não adjacentes)
# 6) Algumas palavras contêm duas vogais que soam como uma apenas. Retire da lista de palavras com duas vogais aquelas que contem um "e" mudo.
# 7) Retire da lista de palavras com duas vogais os ditongos (vogais adjacentes)
# 8) Encontre versículos do Genesis com a palavra "light."

# %%
#1
# !cat ./Dados/genesis.txt | tr -sc 'a-zA-Z' '\012' | egrep -w '[A-Z]*' | sort | uniq | wc -w
# Out:
# 4

# %%
#2
# !cat ./Dados/genesis.txt | tr -sc 'a-zA-Z' '\012' | tr 'A-Z' 'a-z'| egrep '^....$' | sort | uniq | wc -l
# Out:
# 401

# %%
#3
# !cat ./Dados/genesis.txt | tr -sc 'a-zA-Z' '\012' | tr 'A-Z' 'a-z' | grep -v '[aeiouy]' | sort | uniq | sed 's/[a-z]*/yes/g' | uniq
# Out:
# yes

# %%
#4
# !cat ./Dados/genesis.txt | tr -sc 'a-zA-Z' '\012' | tr 'A-Z' 'a-z' | grep [aeiou] | grep -v [aeiou][^aeiou]*[aeiou] | grep -v "ly$" |  sort | uniq | sed 's/[a-z]*/yes/g' | uniq
# Out:
# yes

# %%
#5
# !tr -sc 'a-zA-Z' '\012' < ./Dados/genesis.txt | tr 'A-Z' 'a-z' | grep [aeiou][bcdfghjklmnpqrstvwxyz]*[aeiou] | grep -v [aeiou][a-z]*[aeiou][a-z]*[aeiou] | grep -v '.[aeiou]\{2\}' | sort | uniq
# served
# seven
# sevens
# seventh
# seventy
# sewed
# shadow
# shalem
# shamed
# shammah
# shaved
# shaveh
# sheba
# shebah
# shechem
# sheddeth
# shekel
# shekels
# shelah
# sheleph
# shepherd
# shepherds
# shepho
# shewed
# sheweth
# shillem
# shiloh
# shimron
# shinab
# shinar
# shobal
# shore
# shuni
# sichem
# siddim
# side
# sidon
# signet
# silver
# since
# sinew
# sinners
# sinning
# sister
# sitnah
# slayeth
# slime
# smelled
# smite
# smoke
# smoking
# smote
# sodom
# sole
# solemnly
# some
# sore
# sorely
# sorrow
# sowed
# space
# spake
# spare
# speckled
# spicery
# spices
# spilled
# spirit
# spoken
# sporting
# spotted
# springing
# standest
# state
# stayed
# steward
# stole
# stolen
# stone
# stones
# stopped
# store
# strakes
# strange
# stranger
# strangers
# stretched
# stricken
# strife
# strive
# stronger
# strove
# struggled
# submit
# subtil
# subtilty
# succoth
# summer
# sure
# surely
# surety
# sware
# tabret
# take
# taken
# talked
# talking
# tamar
# tarshish
# tebah
# tema
# teman
# tender
# tenor
# terah
# terror
# thahash
# thence
# there
# thereby
# these
# thicket
# thine
# thistles
# thither
# those
# throne
# tidal
# tidings
# tiller
# tillest
# time
# times
# timna
# timnah
# timnath
# tiras
# tithes
# token
# tola
# toward
# tower
# trade
# traffick
# trembled
# trespass
# tribes
# tubal
# turned
# twelve
# twice
# under
# until
# unto
# upon
# upright
# upward
# urged
# utmost
# uzal
# vale
# valley
# verily
# vessels
# vine
# virgin
# visit
# vowed
# vowedst
# wages
# wagons
# walked
# walketh
# walking
# wander
# washed
# water
# waters
# waxed
# waxen
# wentest
# were
# westward
# whales
# whence
# where
# whereby
# whether
# while
# white
# whither
# whole
# whose
# whoso
# wicked
# wickedly
# widow
# wife
# willing
# window
# windows
# wine
# winged
# winter
# wise
# withheld
# withhold
# within
# witness
# wittingly
# wives
# woman
# women
# worse
# worship
# wotteth
# wrapped
# wrestled
# wrestlings
# yoke
# yonder
# zarah
# zepho
# zerah
# zidon
# zillah
# zilpah
# zimran
# zohar
# zuzims

# %%
#6
# !tr -sc 'a-zA-Z' '\012' < ./Dados/genesis.txt | tr 'A-Z' 'a-z' | grep [aeiou][bcdfghjklmnpqrstvwxyz]*[aeiou] | grep -v [aeiou][a-z]*[aeiou][a-z]*[aeiou] | grep -v '...e[s]*$' | sort | uniq

# %%
#7
# !tr -sc 'a-zA-Z' '\012' < ./Dados/genesis.txt | tr 'A-Z' 'a-z' | grep [aeiou][bcdfghjklmnpqrstvwxyz]*[aeiou] | grep -v [aeiou][a-z]*[aeiou][a-z]*[aeiou] | grep -v '.[aeiou]\{2\}' | sort | uniq

# %%
#8
# !cat ./Dados/genesis.txt | tr 'A-Z' 'a-z' | grep '[ln]ight.*[ln]ight.*[ln]ight' | tr -sc '[0-9]+:[0-9]+' '\n' | grep -v ^: | tr '\n' ', ' | rev | cut -c 2- | rev
# Out:
# 1:14,1:15,1:16,1:17,1:18
